# %%
import pandas as pd
from matplotlib import pyplot as plt

# google_apps_df = pd.read_csv('Datasets/google-play-kaggle/Google-Playstore.csv')
google_apps_df = pd.read_csv('Datasets/google-play-kaggle/Google-Playstore.csv')

# %%
display(google_apps_df.sample(5))
display(google_apps_df.info())
display(google_apps_df.describe())
# Out:
#                                   App Name  \
# 184144         Amharic Ethiopian Game ጢባጢቤ
# 478295                         Gazer Cloud
# 1307134  Lagu Siti Badriah Popular Offline
# 1223865                  Sutel Interactiva
# 1516389          Onraid - Online PVP Brawl
#
#                                            App Id           Category  Rating  \
# 184144                  com.habeshagames.tibatibo             Arcade     4.0
# 478295                  com.gazercloud.global.dvr    Auto & Vehicles     4.6
# 1307134  music.song.collection.sitibadriahpopular      Music & Audio     4.5
# 1223865                com.sutel.sutelinteractiva  Books & Reference     2.5
# 1516389                      com.Pragmatix.Onraid             Action     2.7
#
#          Rating Count  Installs  Minimum Installs  Maximum Installs  Free  \
# 184144          280.0   50,000+           50000.0             63199  True
# 478295           42.0    1,000+            1000.0              1446  True
# ...

# %%
google_apps_selected_df = google_apps_df[['App Name', 'Category',
                                          'Rating', 'Rating Count', 'Minimum Installs',
                                          'Maximum Installs', 'Free', 'Price',
                                          'Size', 'Minimum Android',
                                          'Released', 'Last Updated', 'Content Rating',
                                          'Ad Supported', 'In App Purchases', 'Editors Choice']]

# %% [markdown]
# Discovery

# %%
google_apps_selected_df['Category'].value_counts()
# Out:
# Education                  241090
# Music & Audio              154906
# Tools                      143988
# Business                   143771
# Entertainment              138276
# Lifestyle                  118331
# Books & Reference          116728
# Personalization             89210
# Health & Fitness            83510
# Productivity                79698
# Shopping                    75256
# Food & Drink                73927
# Travel & Local              67288
# Finance                     65466
# Arcade                      53792
# Puzzle                      51168
# Casual                      50813
# Communication               48167
# Sports                      47483
# Social                      44734
# News & Magazines            42807
# Photography                 35552
# Medical                     32065
# Action                      27555
# Maps & Navigation           26722
# Simulation                  23282
# Adventure                   23203
# ...

# %% [markdown]
# Export CSV

# %%
google_apps_selected_df.to_csv('Datasets/google-play-kaggle/Google-Playstore-selected.csv', index=False)

# %% [markdown]
# Sub-dataset

# %%
google_apps_sample_df = google_apps_selected_df.sample(200000)

# %%
google_apps_sample_df.to_csv('Datasets/google-play-kaggle/Google-Playstore-sample.csv', index=False)
